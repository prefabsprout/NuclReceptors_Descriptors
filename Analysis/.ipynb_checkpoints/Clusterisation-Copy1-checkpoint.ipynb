# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans, AgglomerativeClustering
from scipy.cluster import hierarchy
from sklearn import metrics
from scipy.spatial.distance import pdist
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %% [markdown]
# Read our dataset:

# %%
nucl_data = pd.read_csv('calc_res_fulldata.csv', 
                        sep = ',')
nucl_data = nucl_data.drop(['X','preparation', 'prot_name'],axis=1)
nucl_data
# Out:
#     species_name  Prot_Helix_1_distance  Prot_Helix_2_distance  \
# 0          human              17.974863              26.547784
# 1            rat              17.390721               9.255170
# 2      zebrafish              18.294092               9.244250
# 3          human              19.061009              26.254811
# 4            rat              18.960795               9.245280
# ..           ...                    ...                    ...
# 297          rat              18.738154               9.518681
# 298          rat              17.215085               9.483004
# 299          rat              19.301802               8.785279
# 300          rat              17.431857               9.471029
# 301          rat              18.359869               9.067002
#
#      Prot_Helix_3_distance  Prot_Helix_4_distance  Prot_Helix_5_distance  \
# 0                 9.791820               9.071770              17.886196
# 1                 7.282463              18.820273              13.321717
# 2                 7.300175              19.560526              13.835443
# 3                 9.776772              16.074603               1.132875
# 4                 8.551828              12.643492              10.452929
# ..                     ...                    ...                    ...
# 297               8.411953              17.891059              12.969316
# 298               7.871503              18.741791              13.687987
# 299               8.415296              17.802714              13.044033
# 300               7.912497              18.710965              13.579022
# 301               8.213224              17.720538              12.989879
#
#      Prot_Helix_6_distance  Prot_Helix_7_distance  Prot_Helix_8_distance  \
# 0                12.491443              10.047880              19.065880
# 1                 9.896496              18.675770              10.318261
# 2                 9.855815              18.557269              10.195871
# 3                17.548993              12.363952              10.217229
# 4                19.452348               9.942127              24.492728
# ..                     ...                    ...                    ...
# 297              10.153988              19.126126              10.218089
# 298               9.614174              18.486648              10.351234
# 299              10.855968              19.629493              10.012144
# 300               9.922151              18.766483              10.413419
# 301              10.803647              19.713750               9.927934
#
#      Prot_Helix_9_distance  ...  Angle_between_COM_and_Calpha_of_hel_6  \
# 0                 9.956600  ...                              14.030842
# 1                24.607442  ...                               1.226074
# 2                24.609094  ...                               1.044740
# 3                19.196752  ...                              53.323231
# 4                15.771120  ...                               8.330556
# ..                     ...  ...                                    ...
# 297              24.509876  ...                               2.768396
# 298              24.798373  ...                              -1.201638
# 299              23.801385  ...                               7.391420
# 300              24.532342  ...                               0.829831
# 301              23.889577  ...                               7.448712
#
#      Angle_between_COM_and_Calpha_of_hel_7  \
# 0                                 2.623092
# 1                                 6.150571
# 2                                15.244886
# 3                                13.209491
# 4                               -44.147992
# ..                                     ...
# 297                               7.741541
# 298                               5.404590
# 299                              16.025997
# 300                               6.417445
# 301                              16.284516
#
#      Angle_between_COM_and_Calpha_of_hel_8  \
# 0                                 7.676063
# 1                               -42.244937
# 2                               -42.725393
# 3                                 4.239240
# 4                                57.133413
# ..                                     ...
# 297                             -42.867106
# 298                             -40.834158
# 299                             -43.689580
# 300                             -40.145995
# 301                             -44.239955
#
#      Angle_between_COM_and_Calpha_of_hel_9  \
# 0                               -43.763860
# 1                                57.144269
# 2                                57.210145
# 3                                 7.651877
# 4                                51.881098
# ..                                     ...
# 297                              57.124091
# 298                              57.100592
# 299                              57.140055
# 300                              57.150244
# 301                              57.133874
#
#      Angle_between_COM_and_Calpha_of_hel_10  \
# 0                                 48.972919
# 1                                 48.842916
# 2                                 52.251289
# 3                                -39.745646
# 4                                       NaN
# ..                                      ...
# 297                               48.943928
# 298                               49.096946
# 299                               51.551273
# 300                               49.388597
# 301                               47.920722
#
#      Angle_between_COM_and_Calpha_of_hel_11  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                 55.832362
# 4                                       NaN
# ..                                      ...
# 297                                     NaN
# 298                                     NaN
# 299                                     NaN
# 300                                     NaN
# 301                                     NaN
#
#      Angle_between_COM_and_Calpha_of_hel_12      COM_x      COM_y      COM_z
# 0                                       NaN  13.349842  20.147798  41.787953
# 1                                       NaN  18.290441  -6.193724  18.697197
# 2                                       NaN   8.653866  37.391085  42.200621
# 3                                 52.090991  13.233800  20.638833  41.367259
# 4                                       NaN  18.216867   0.543652  19.482196
# ..                                      ...        ...        ...        ...
# 297                                     NaN  14.426456  -4.968180  61.244284
# 298                                     NaN  56.289998  -0.701228   1.823249
# 299                                     NaN  17.628527   4.691382  19.826932
# 300                                     NaN  18.395058   4.049283  19.032577
# 301                                     NaN  17.667980  -1.209375  19.929294
#
# [302 rows x 133 columns]

# %% [markdown]
# And look on descriptive statistics:

# %%
nucl_data.describe()
# Out:
#        Prot_Helix_1_distance  Prot_Helix_2_distance  Prot_Helix_3_distance  \
# count             292.000000             292.000000             292.000000
# mean               18.720194              14.622227               8.671512
# std                 2.629035               7.914337               1.947697
# min                16.444871               6.277105               6.528308
# 25%                17.524049               9.170367               7.391522
# 50%                18.298725               9.473324               8.213486
# 75%                19.093379              26.153864               9.787758
# max                38.727923              26.782293              22.066224
#
#        Prot_Helix_4_distance  Prot_Helix_5_distance  Prot_Helix_6_distance  \
# count             292.000000             292.000000             292.000000
# mean               16.015811              13.888250              11.877266
# std                 4.154383               4.493942               3.249789
# min                 7.458123               1.010671               9.090923
# 25%                13.264096              13.206382               9.947849
# 50%                17.810692              13.765623              10.746683
# 75%                18.918572              17.206145              12.353288
# max                24.584388              37.207158              29.850100
#
#        Prot_Helix_7_distance  Prot_Helix_8_distance  Prot_Helix_9_distance  \
# count             292.000000             292.000000             291.000000
# mean               16.078544              13.037495              20.044450
# std                 4.438193               4.505923               6.273507
# min                 5.496619               6.365984               9.581607
# 25%                10.353423              10.192563              14.354709
# 50%                18.392721              10.333697              23.985961
# 75%                18.793473              18.866514              24.626462
# max                37.017886              24.670410              29.666896
#
#        Prot_Helix_10_distance  ...  Angle_between_COM_and_Calpha_of_hel_6  \
# count              273.000000  ...                             292.000000
# mean                15.762246  ...                               9.836906
# std                  3.809581  ...                              14.069514
# min                  9.633122  ...                              -6.421688
# 25%                 14.671781  ...                               1.497262
# 50%                 15.118263  ...                               6.490166
# 75%                 15.403916  ...                              12.965548
# max                 41.737889  ...                              53.951038
#
#        Angle_between_COM_and_Calpha_of_hel_7  \
# count                             292.000000
# mean                                6.202876
# std                                11.558911
# min                               -47.735795
# 25%                                 4.057846
# 50%                                 5.918674
# 75%                                10.120024
# max                                55.300101
#
#        Angle_between_COM_and_Calpha_of_hel_8  \
# count                             292.000000
# mean                              -21.637252
# std                                27.359109
# min                               -44.732368
# 25%                               -42.515333
# 50%                               -39.127628
# 75%                                 6.601475
# max                                57.196625
#
#        Angle_between_COM_and_Calpha_of_hel_9  \
# count                             291.000000
# mean                               29.462813
# std                                42.403499
# min                               -48.532281
# 25%                                 7.631013
# 50%                                57.105418
# 75%                                57.152317
# max                                57.220922
#
#        Angle_between_COM_and_Calpha_of_hel_10  \
# count                              273.000000
# mean                                44.473844
# std                                 23.939351
# min                                -45.097471
# 25%                                 48.903355
# 50%                                 49.601550
# 75%                                 52.129301
# max                                 57.268933
#
#        Angle_between_COM_and_Calpha_of_hel_11  \
# count                               53.000000
# mean                                50.747454
# std                                  1.822942
# min                                 48.487500
# 25%                                 49.105858
# 50%                                 49.794497
# 75%                                 52.168772
# max                                 55.832362
#
#        Angle_between_COM_and_Calpha_of_hel_12       COM_x       COM_y  \
# count                                2.000000  302.000000  302.000000
# mean                                46.055459   13.760621   12.414138
# std                                  8.535532   21.062161   15.636453
# min                                 40.019926  -30.443267  -21.930911
# 25%                                 43.037692    8.845826   -0.206680
# 50%                                 46.055459   13.359436    4.618507
# 75%                                 49.073225   18.000074   21.010009
# max                                 52.090991  172.456557   39.236476
#
#             COM_z
# count  302.000000
# mean    22.830585
# std     21.077582
# min    -24.451273
# 25%     13.957350
# 50%     19.793366
# 75%     41.842361
# max     61.244284
#
# [8 rows x 132 columns]

# %% [markdown]
# While we try to cluster our data in last time we found that data have some outliers. So we'll remove it.

# %%
# nucl_data_without_class_and_max = nucl_data_without_class.drop(nucl_data_without_class['Prot_Helix_1_distance'].idxmax())
largest = nucl_data['Prot_Helix_1_distance'].nlargest(5)
nucl_data_without_max = nucl_data[~nucl_data.Prot_Helix_1_distance.isin(largest)]

# %% [markdown]
# Next let clean our data from totally empty (or mainly empty) columns. And drop observations with NaN.

# %%
nucl_data_without_nan = nucl_data_without_max.drop(['Angle_between_COM_and_Calpha_of_hel_11', 'Angle_between_COM_and_Calpha_of_hel_12',
                                       'COM_helix_z_num_12','COM_helix_y_num_12','COM_helix_x_num_12',
                                       'COM_helix_x_num_11','COM_helix_y_num_11','COM_helix_z_num_11',
                                       'Pairwise_sep_between_hel_6_and_hel_7', 'Pairwise_sep_between_hel_6_and_hel_8',
                                       'Pairwise_sep_between_hel_6_and_hel_9', 'Pairwise_sep_between_hel_6_and_hel_10',
                                       'Pairwise_sep_between_hel_6_and_hel_11', 'Pairwise_sep_between_hel_6_and_hel_12',
                                       'Pairwise_sep_between_hel_7_and_hel_8','Pairwise_sep_between_hel_7_and_hel_9',
                                       'Pairwise_sep_between_hel_7_and_hel_10', 'Pairwise_sep_between_hel_7_and_hel_11',
                                       'Pairwise_sep_between_hel_7_and_hel_11', 'Pairwise_sep_between_hel_7_and_hel_12',
                                        'Pairwise_sep_between_hel_8_and_hel_9',
                                       'Pairwise_sep_between_hel_8_and_hel_10','Pairwise_sep_between_hel_8_and_hel_11',
                                       'Pairwise_sep_between_hel_8_and_hel_12', 'Pairwise_sep_between_hel_9_and_hel_10',
                                       'Pairwise_sep_between_hel_9_and_hel_11','Pairwise_sep_between_hel_9_and_hel_12',
                                       'Pairwise_sep_between_hel_10_and_hel_11', 'Pairwise_sep_between_hel_10_and_hel_12',
                                       'Pairwise_sep_between_hel_11_and_hel_12','Prot_Helix_11_distance',
                                       'Prot_Helix_12_distance'],axis=1)
nucl_data_without_nan = nucl_data_without_nan.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
nucl_data_without_nan
# Out:
#     species_name  Prot_Helix_1_distance  Prot_Helix_2_distance  \
# 0          human              17.974863              26.547784
# 1            rat              17.390721               9.255170
# 2      zebrafish              18.294092               9.244250
# 3          human              19.061009              26.254811
# 5      zebrafish              18.346824               9.557283
# ..           ...                    ...                    ...
# 297          rat              18.738154               9.518681
# 298          rat              17.215085               9.483004
# 299          rat              19.301802               8.785279
# 300          rat              17.431857               9.471029
# 301          rat              18.359869               9.067002
#
#      Prot_Helix_3_distance  Prot_Helix_4_distance  Prot_Helix_5_distance  \
# 0                 9.791820               9.071770              17.886196
# 1                 7.282463              18.820273              13.321717
# 2                 7.300175              19.560526              13.835443
# 3                 9.776772              16.074603               1.132875
# 5                 7.256810              19.109201              13.815876
# ..                     ...                    ...                    ...
# 297               8.411953              17.891059              12.969316
# 298               7.871503              18.741791              13.687987
# 299               8.415296              17.802714              13.044033
# 300               7.912497              18.710965              13.579022
# 301               8.213224              17.720538              12.989879
#
#      Prot_Helix_6_distance  Prot_Helix_7_distance  Prot_Helix_8_distance  \
# 0                12.491443              10.047880              19.065880
# 1                 9.896496              18.675770              10.318261
# 2                 9.855815              18.557269              10.195871
# 3                17.548993              12.363952              10.217229
# 5                 9.954191              18.267517              10.242193
# ..                     ...                    ...                    ...
# 297              10.153988              19.126126              10.218089
# 298               9.614174              18.486648              10.351234
# 299              10.855968              19.629493              10.012144
# 300               9.922151              18.766483              10.413419
# 301              10.803647              19.713750               9.927934
#
#      Prot_Helix_9_distance  ...  Angle_between_COM_and_Calpha_of_hel_4  \
# 0                 9.956600  ...                             -28.134270
# 1                24.607442  ...                              55.215760
# 2                24.609094  ...                              54.062219
# 3                19.196752  ...                              45.047160
# 5                24.659428  ...                              54.213521
# ..                     ...  ...                                    ...
# 297              24.509876  ...                              53.766404
# 298              24.798373  ...                              54.094324
# 299              23.801385  ...                              53.953962
# 300              24.532342  ...                              54.267716
# 301              23.889577  ...                              53.795849
#
#      Angle_between_COM_and_Calpha_of_hel_5  \
# 0                                53.883654
# 1                                17.468010
# 2                                33.093973
# 3                               -45.806284
# 5                                20.193228
# ..                                     ...
# 297                              17.366851
# 298                              19.424467
# 299                              16.732478
# 300                              19.202382
# 301                              15.646850
#
#      Angle_between_COM_and_Calpha_of_hel_6  \
# 0                                14.030842
# 1                                 1.226074
# 2                                 1.044740
# 3                                53.323231
# 5                                 1.312308
# ..                                     ...
# 297                               2.768396
# 298                              -1.201638
# 299                               7.391420
# 300                               0.829831
# 301                               7.448712
#
#      Angle_between_COM_and_Calpha_of_hel_7  \
# 0                                 2.623092
# 1                                 6.150571
# 2                                15.244886
# 3                                13.209491
# 5                                 4.462589
# ..                                     ...
# 297                               7.741541
# 298                               5.404590
# 299                              16.025997
# 300                               6.417445
# 301                              16.284516
#
#      Angle_between_COM_and_Calpha_of_hel_8  \
# 0                                 7.676063
# 1                               -42.244937
# 2                               -42.725393
# 3                                 4.239240
# 5                               -41.344808
# ..                                     ...
# 297                             -42.867106
# 298                             -40.834158
# 299                             -43.689580
# 300                             -40.145995
# 301                             -44.239955
#
#      Angle_between_COM_and_Calpha_of_hel_9  \
# 0                               -43.763860
# 1                                57.144269
# 2                                57.210145
# 3                                 7.651877
# 5                                57.169116
# ..                                     ...
# 297                              57.124091
# 298                              57.100592
# 299                              57.140055
# 300                              57.150244
# 301                              57.133874
#
#      Angle_between_COM_and_Calpha_of_hel_10      COM_x      COM_y      COM_z
# 0                                 48.972919  13.349842  20.147798  41.787953
# 1                                 48.842916  18.290441  -6.193724  18.697197
# 2                                 52.251289   8.653866  37.391085  42.200621
# 3                                -39.745646  13.233800  20.638833  41.367259
# 5                                 52.140192   8.921625  36.463007  42.442288
# ..                                      ...        ...        ...        ...
# 297                               48.943928  14.426456  -4.968180  61.244284
# 298                               49.096946  56.289998  -0.701228   1.823249
# 299                               51.551273  17.628527   4.691382  19.826932
# 300                               49.388597  18.395058   4.049283  19.032577
# 301                               47.920722  17.667980  -1.209375  19.929294
#
# [258 rows x 102 columns]

# %% [markdown]
# Great. We have some prepared data to analysis. First let look on scatter plot with species.

# %%
sns.relplot(x = 'Prot_Helix_1_distance', 
            y = 'Prot_Helix_2_distance', 
            hue='species_name', data = nucl_data_without_nan)

# %% [markdown]
# Next we gonna drop species_name. Because we don't need categorical variables in our analysis.

# %%
nucl_data_without_class = nucl_data_without_nan.drop(['species_name'], axis=1)

# %% [markdown]
# Ok. Let calculate optimal number of clusters.

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(nucl_data_without_class)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# Great. Optimal number of clusters equals 7. Let build our k-means model with k-means++ for better calculating of centroids.

# %%
k_means_nucl = KMeans(n_clusters=7,  n_init=100, init='k-means++', max_iter=10000000)
y_kmeans = k_means_nucl.fit_predict(nucl_data_without_class)
nucl_data_without_class['y_kmeans'] = y_kmeans

# %% [markdown]
# We will use TSNE algorythm for proper data visualisation.

# %%
nucl_data_embeded = TSNE(n_components=2).fit_transform(nucl_data_without_class)
nucl_data_embeded_dataframed = pd.DataFrame(nucl_data_embeded, columns=['Feature 0', 'Feature 1'])
nucl_data_embeded_dataframed = pd.concat([nucl_data_embeded_dataframed, pd.Series(y_kmeans, name='clusters').astype('category')], axis=1, sort=False)
nucl_data_embeded_dataframed
# Out:
#      Feature 0  Feature 1 clusters
# 0    -5.987022  20.701473        1
# 1    -5.717547 -14.523614        0
# 2    17.951950   8.722011        2
# 3     3.066040  16.111912        3
# 4    19.518644   7.082322        2
# ..         ...        ...      ...
# 253  -4.321925 -19.248703        0
# 254 -12.057673 -14.507205        4
# 255   0.845700 -14.031692        0
# 256  -4.706647 -11.185843        0
# 257  -1.364602 -13.695498        0
#
# [258 rows x 3 columns]

# %% [markdown]
# And finally visualise it.

# %%
sns.scatterplot(x="Feature 0", y='Feature 1', 
                hue='clusters',
                     data=nucl_data_embeded_dataframed)

# %%
nucl_data_embeded = PCA(n_components=2).fit_transform(nucl_data_without_class)
nucl_data_embeded_dataframed = pd.DataFrame(nucl_data_embeded, columns=['Feature 0', 'Feature 1'])
nucl_data_embeded_dataframed = pd.concat([nucl_data_embeded_dataframed, pd.Series(y_kmeans, name='clusters').astype('category')], axis=1, sort=False)
nucl_data_embeded_dataframed
# Out:
#       Feature 0   Feature 1 clusters
# 0    110.010384  -98.843833        1
# 1    -50.647068   54.146466        0
# 2    -78.506144  -79.928991        2
# 3     34.738507 -102.320435        3
# 4    -80.610907  -77.206662        2
# ..          ...         ...      ...
# 253  -83.384252  -62.791084        0
# 254  -43.161254  117.525579        4
# 255  -52.811627   36.528814        0
# 256  -53.576807   37.227422        0
# 257  -53.046882   45.169170        0
#
# [258 rows x 3 columns]

# %%
sns.scatterplot(x="Feature 0", y='Feature 1', 
                hue='clusters',
                     data=nucl_data_embeded_dataframed)
